# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from keras.models import Sequential,Model
from keras.layers import Dense,Activation,Input
from keras.utils import np_utils

# %%
data = pd.read_csv("../class_10/fashion-mnist_test.csv")
data = data.values

# %%
X = data[:,1:]
y = data[:,0]

X = X/255.0
y = np_utils.to_categorical(y)

# %%
print (X.shape,y.shape)
# Out:
# ((10000, 784), (10000, 10))

# %%
for ix in range(10):
    x = X[ix].reshape(28,28)
    plt.imshow(x)
    plt.show()

# %%
# using sequential API

model = Sequential()
model.add(Dense(256, input_dim=(784)))
model.add(Activation('relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 256)               200960
# _________________________________________________________________
# activation_7 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                650
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# =================================================================
# Total params: 218,058
# Trainable params: 218,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
## using functional API

inp = Input(shape=(784,))
h1 = Dense(256,activation='relu')(inp)
h2 = Dense(64,activation='relu')(h1)
h2 = Dense(10)(h2)

out = Activation('softmax')(h2)

model = Model(inputs=inp,outputs=out)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                650
# _________________________________________________________________
# activation_10 (Activation)   (None, 10)                0
# =================================================================
# Total params: 218,058
# Trainable params: 218,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
hist = model.fit(X,y,epochs=20,shuffle=True,batch_size=256,validation_split=0.20)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/20
# 8000/8000 [==============================] - 1s 131us/step - loss: 1.0468 - acc: 0.6575 - val_loss: 0.6514 - val_acc: 0.7860
# Epoch 2/20
# 8000/8000 [==============================] - 1s 66us/step - loss: 0.5796 - acc: 0.7996 - val_loss: 0.6210 - val_acc: 0.7765
# Epoch 3/20
# 8000/8000 [==============================] - 1s 66us/step - loss: 0.5320 - acc: 0.8130 - val_loss: 0.5330 - val_acc: 0.8105
# Epoch 4/20
# 8000/8000 [==============================] - 1s 64us/step - loss: 0.4512 - acc: 0.8465 - val_loss: 0.4362 - val_acc: 0.8535
# Epoch 5/20
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.4259 - acc: 0.8514 - val_loss: 0.4355 - val_acc: 0.8505
# Epoch 6/20
# 8000/8000 [==============================] - 1s 66us/step - loss: 0.4318 - acc: 0.8454 - val_loss: 0.4231 - val_acc: 0.8485
# Epoch 7/20
# 8000/8000 [==============================] - 1s 75us/step - loss: 0.3914 - acc: 0.8618 - val_loss: 0.4023 - val_acc: 0.8575
# Epoch 8/20
# 8000/8000 [==============================] - 1s 67us/step - loss: 0.3561 - acc: 0.8722 - val_loss: 0.3982 - val_acc: 0.8605
# Epoch 9/20
# 8000/8000 [==============================] - 1s 67us/step - loss: 0.3571 - acc: 0.8714 - val_loss: 0.4258 - val_acc: 0.8540
# Epoch 10/20
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.3345 - acc: 0.8798 - val_loss: 0.3921 - val_acc: 0.8655
# Epoch 11/20
# 8000/8000 [==============================] - 1s 70us/step - loss: 0.3173 - acc: 0.8880 - val_loss: 0.4324 - val_acc: 0.8495
# Epoch 12/20
# 8000/8000 [==============================] - 1s 90us/step - loss: 0.3214 - acc: 0.8822 - val_loss: 0.3815 - val_acc: 0.8645
# Epoch 13/20
# 8000/8000 [==============================] - 1s 63us/step - loss: 0.2966 - acc: 0.8924 - val_loss: 0.3941 - val_acc: 0.8600
# Epoch 14/20
# 8000/8000 [==============================] - 0s 62us/step - loss: 0.2874 - acc: 0.8941 - val_loss: 0.4095 - val_acc: 0.8500
# Epoch 15/20
# 8000/8000 [==============================] - 0s 61us/step - loss: 0.2828 - acc: 0.8965 - val_loss: 0.3723 - val_acc: 0.8740
# Epoch 16/20
# 8000/8000 [==============================] - 1s 63us/step - loss: 0.2666 - acc: 0.9034 - val_loss: 0.3888 - val_acc: 0.8635
# Epoch 17/20
# 8000/8000 [==============================] - 0s 60us/step - loss: 0.2590 - acc: 0.9071 - val_loss: 0.3676 - val_acc: 0.8695
# Epoch 18/20
# 8000/8000 [==============================] - 1s 64us/step - loss: 0.2497 - acc: 0.9096 - val_loss: 0.3908 - val_acc: 0.8635
# Epoch 19/20
# 8000/8000 [==============================] - 0s 62us/step - loss: 0.2448 - acc: 0.9121 - val_loss: 0.3854 - val_acc: 0.8660
# Epoch 20/20
# 8000/8000 [==============================] - 0s 62us/step - loss: 0.2441 - acc: 0.9113 - val_loss: 0.3803 - val_acc: 0.8685

# %%
#adam

plt.figure(1)
plt.plot(hist.history['acc'], color = 'r')
plt.plot(hist.history['val_acc'], color = 'b')

plt.figure(2)
plt.plot(hist.history['loss'], color = 'r')
plt.plot(hist.history['val_loss'], color = 'b')

# %%
#sgd

plt.figure(1)
plt.plot(hist.history['acc'], color = 'r')
plt.plot(hist.history['val_acc'], color = 'b')

plt.figure(2)
plt.plot(hist.history['loss'], color = 'r')
plt.plot(hist.history['val_loss'], color = 'b')
