# %% [markdown]
# ### Libraries to be used
#
# - Numpy
# - Matplotlib
# - Pandas
# - OpenCV

# %%
# import the libraries

import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import cv2
import skimage.io as io

# %% [markdown]
# ### Numpy Arrays and Operations

# %%
# Convert lists to numpy arrays
lis = [[1,2],[8,9]]
arr1 = np.array(lis, dtype=np.uint8)
arr2 = np.asarray(lis, dtype=np.uint16)

#print (lis, type(lis))
#print (arr1, type(arr1), arr1.dtype)
#print (arr2, type(arr2), arr2.dtype)


# Create New numpy arrays

arr_zero = np.zeros((5,4))
#print (arr_zero, arr_zero.shape)

arr_i = np.eye(4)

arr_i[2][3] = 5

#print (arr_i, arr_i.shape)


# Copy numpy arrays

arr_c = arr1.copy()
#print (arr_c)

# Shapes of numpy arrays and multi-dimensional arrays
arr3 = np.random.randint(low=-10, high =10, size=(4,5))
#print (arr3)

# Reshape, Transpose, Concatenate numpy arrays
arr4 = arr3.reshape((2,10))
#print (arr4, arr4.shape)

# Transpose
#print (arr4.T, arr4.T.shape)



arr6 = np.array([[2,4,4], [4,5,6]])
arr7 = np.array([[2,6,9], [3,5,6]])

C = np.concatenate((arr6,arr7),axis = 1) # join columns
C = np.concatenate((arr6,arr7),axis = 0) # join rows
#print (C,C.shape)

C = np.concatenate( ( np.expand_dims(arr6, axis=0), np.expand_dims(arr7, axis=0) ), axis =0 )
#print (C, C.shape)

# %% [markdown]
# ### Matplotlib

# %%
plt.style.available
# Out:
# ['seaborn-darkgrid',
#  'Solarize_Light2',
#  'seaborn-notebook',
#  'classic',
#  'seaborn-ticks',
#  'grayscale',
#  'bmh',
#  'seaborn-talk',
#  'dark_background',
#  'ggplot',
#  'fivethirtyeight',
#  '_classic_test',
#  'seaborn-colorblind',
#  'seaborn-deep',
#  'seaborn-whitegrid',
#  'seaborn-bright',
#  'seaborn-poster',
#  'seaborn-muted',
#  'seaborn-paper',
#  'seaborn-white',
#  'fast',
#  'seaborn-pastel',
#  'seaborn-dark',
#  'tableau-colorblind10',
#  'seaborn',
#  'seaborn-dark-palette']

# %%
# plot simple ranges
plt.style.use("seaborn-darkgrid")
a = np.array(range(0,100,2))
b = np.array(range(0,100,2))

plt.figure(0)
plt.title("Line")
plt.grid("on")
plt.xlabel("year")
plt.xlim(0,100)
plt.ylabel("sales")
plt.ylim(0,100)
plt.plot(a,b,'r',label="Dec")
plt.scatter(a,2*a,c='g',label="Nov",marker="*")
plt.legend()
plt.show()

# %%
# Plot sine wave, cosine wave, and some lines

x = np.linspace(-2*np.pi, 2*np.pi, num=100)
plt.figure(0)
plt.scatter(x, np.sin(x), c='r')
plt.plot(x, np.cos(x), 'g')
plt.show()

# %% [markdown]
# ### OpenCV and Scikit-Image

# %%
# Loading an image
img = cv2.imread("./download.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


# Dispalying an image
plt.imshow(img)

# Convert image to grayscale
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(img, cmap='gray')

# Resize image
print (img.shape)
img = cv2.resize(img, (250,150)) # (columns,rows)
plt.imshow(img, cmap='gray')
# Out:
# (340, 537)

# %% [markdown]
# ### Pandas

# %%
# Load the movie meta-data dataset
data = pd.read_csv("./movie_metadata.csv")

#data.head(5)
data.tail(5)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  \
# 5038                   637.0      NaN                  Comedy|Drama
# 5039                   841.0      NaN  Crime|Drama|Mystery|Thriller
# 5040                     0.0      NaN         Drama|Horror|Thriller
# 5041                   946.0  10443.0          Comedy|Drama|Romance
# 5042                    86.0  85222.0                   Documentary
#
#              ...          num_user_for_reviews language  country  \
# 5038         ...                           6.0  English   Canada
# 5039         ...                         359.0  English      USA
# 5040         ...                           3.0  English      USA
# 5041         ...                           9.0  English      USA
# 5042         ...                          84.0  English      USA
#
#       content_rating  budget  title_year actor_2_facebook_likes imdb_score  \
# 5038             NaN     NaN      2013.0                  470.0        7.7
# 5039           TV-14     NaN         NaN                  593.0        7.5
# 5040             NaN  1400.0      2013.0                    0.0        6.3
# 5041           PG-13     NaN      2012.0                  719.0        6.3
# 5042              PG  1100.0      2004.0                   23.0        6.6
#
#       aspect_ratio movie_facebook_likes
# 5038           NaN                   84
# 5039         16.00                32000
# 5040           NaN                   16
# 5041          2.35                  660
# 5042          1.85                  456
#
# [5 rows x 28 columns]

# %%
data_u = data.drop('duration',axis=1, inplace=False)

data_u.head(5)
# Out:
#        director_name  num_critic_for_reviews  director_facebook_likes  \
# 0      James Cameron                   723.0                      0.0
# 1     Gore Verbinski                   302.0                    563.0
# 2         Sam Mendes                   602.0                      0.0
# 3  Christopher Nolan                   813.0                  22000.0
# 4        Doug Walker                     NaN                    131.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
# 3                 23000.0    Christian Bale                 27000.0
# 4                     NaN        Rob Walker                   131.0
#
#          gross                           genres     actor_1_name  \
# 0  760505847.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1  309404152.0         Action|Adventure|Fantasy      Johnny Depp
# 2  200074175.0        Action|Adventure|Thriller  Christoph Waltz
# 3  448130642.0                  Action|Thriller        Tom Hardy
# 4          NaN                      Documentary      Doug Walker
#
#                                          movie_title         ...           \
# 0                                            Avatar          ...
# 1          Pirates of the Caribbean: At World's End          ...
# 2                                           Spectre          ...
# 3                             The Dark Knight Rises          ...
# 4  Star Wars: Episode VII - The Force Awakens    ...         ...
#
#    num_user_for_reviews  language country  content_rating       budget  \
# 0                3054.0   English     USA           PG-13  237000000.0
# 1                1238.0   English     USA           PG-13  300000000.0
# 2                 994.0   English      UK           PG-13  245000000.0
# 3                2701.0   English     USA           PG-13  250000000.0
# 4                   NaN       NaN     NaN             NaN          NaN
#
#   title_year  actor_2_facebook_likes imdb_score aspect_ratio  \
# 0     2009.0                   936.0        7.9         1.78
# 1     2007.0                  5000.0        7.1         2.35
# 2     2015.0                   393.0        6.8         2.35
# 3     2012.0                 23000.0        8.5         2.35
# 4        NaN                    12.0        7.1          NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# plot_keywords                4890 non-null object
# movie_imdb_link              5043 non-null object
# num_user_for_reviews         5022 non-null float64
# language                     5031 non-null object
# country                      5038 non-null object
# content_rating               4740 non-null object
# budget                       4551 non-null float64
# title_year                   4935 non-null float64
# actor_2_facebook_likes       5030 non-null float64
# imdb_score                   5043 non-null float64
# aspect_ratio                 4714 non-null float64
# movie_facebook_likes         5043 non-null int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3757 entries, 0 to 5042
# Data columns (total 27 columns):
# director_name                3757 non-null object
# num_critic_for_reviews       3757 non-null float64
# duration                     3757 non-null float64
# director_facebook_likes      3757 non-null float64
# actor_3_facebook_likes       3757 non-null float64
# actor_2_name                 3757 non-null object
# actor_1_facebook_likes       3757 non-null float64
# gross                        3757 non-null float64
# genres                       3757 non-null object
# actor_1_name                 3757 non-null object
# movie_title                  3757 non-null object
# num_voted_users              3757 non-null int64
# cast_total_facebook_likes    3757 non-null int64
# actor_3_name                 3757 non-null object
# facenumber_in_poster         3757 non-null float64
# plot_keywords                3757 non-null object
# movie_imdb_link              3757 non-null object
# num_user_for_reviews         3757 non-null float64
# language                     3757 non-null object
# country                      3757 non-null object
# content_rating               3757 non-null object
# budget                       3757 non-null float64
# title_year                   3757 non-null float64
# actor_2_facebook_likes       3757 non-null float64
# imdb_score                   3757 non-null float64
# aspect_ratio                 3757 non-null float64
# movie_facebook_likes         3757 non-null int64
# dtypes: float64(13), int64(3), object(11)
# memory usage: 821.8+ KB

# %%
# Get the values as numpy array and check shape
movie_data = data.values

movie_data.shape
# Out:
# (5043, 28)

# %%
# Print all columns
data.columns
# Out:
# Index([u'color', u'director_name', u'num_critic_for_reviews', u'duration',
#        u'director_facebook_likes', u'actor_3_facebook_likes', u'actor_2_name',
#        u'actor_1_facebook_likes', u'gross', u'genres', u'actor_1_name',
#        u'movie_title', u'num_voted_users', u'cast_total_facebook_likes',
#        u'actor_3_name', u'facenumber_in_poster', u'plot_keywords',
#        u'movie_imdb_link', u'num_user_for_reviews', u'language', u'country',
#        u'content_rating', u'budget', u'title_year', u'actor_2_facebook_likes',
#        u'imdb_score', u'aspect_ratio', u'movie_facebook_likes'],
#       dtype='object')

# %%
# Print a few movie titles
movie_titles = data.get("movie_title")

#movie_titles.head(5)
movie_titles.tail(5)
# Out:
# 5038      Signed Sealed Delivered
# 5039    The Following
# 5040         A Plague So Pleasant
# 5041             Shanghai Calling
# 5042            My Date with Drew
# Name: movie_title, dtype: object

# %% [markdown]
# ### Mean, Variance, Std. Dev.
#
# Mean:
#
# $$\mu = \frac{\sum_{i}{x_i}}{N}$$
#
# Variance:
#
# $$ Var(x) = \frac{\sum_i(x_i - \mu)^2}{N} $$
#
# Std. deviation:
#
# $$ \sigma_x = \sqrt{\frac{\sum_i(x_i - \mu)^2}{N}} $$
#
# ### Co-Variance
#
# $$
# \Sigma =
# \begin{bmatrix}
#     \sigma^2_{11}       & \sigma^2_{12} & \sigma^2_{13} & \dots & \sigma^2_{1n} \\
#     \sigma^2_{21}       & \sigma^2_{22} & \sigma^2_{23} & \dots & \sigma^2_{2n} \\
#     \dots \\
#     \sigma^2_{n1}       & \sigma^2_{n2} & \sigma^2_{n3} & \dots & \sigma^2_{nn}
# \end{bmatrix}
# $$

# %% [markdown]
# 1. __Random Variable__
# 2. __Distribution Function__:
#     - The _cumulative distribution function_: $F_X(x) = \mathbb{P}(X \leq x)$
#     - Bernoulli Distribution function: $f(x) = p^x(1-p)^{1-x};   x \in \{0, 1\}$
#     - Binomial distribution...
# 3. __Normal Distribution__:
# $$ f(x) = \frac{1}{\sigma \sqrt{2 \pi}} exp\{- \frac{1}{2 \sigma^2} (x - \mu)^2 \} $$
# 4. __Standard Normal Distribution__

# %%
# Create and plot frequency of each title length
len_movies = [len(ix) for ix in movie_titles.values]

freq = {}
for ix in len_movies:
    if ix in freq.keys():
        freq[ix] += 1
    else :
        freq[ix] = 1

# %%
plt.plot(freq.keys(),freq.values())
plt.show()

# %% [markdown]
# ### Assignment-2

# %%
# Generating random numbers

# (a:0.5, b:0.2, c:0.3)

# %%
# Plot Random numbers as scatter plot

# %%
# Generate Normal distribution in 2D

# %%
# Convert to Standard Normal Distribution

# %%
# plot the normal and standard normal distribution.
